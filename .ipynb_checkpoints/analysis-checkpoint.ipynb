# %%
import pandas as pd
import numpy as np

# %%
matches = pd.read_csv(r'CSV Files\ipl-matches.csv')
matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
list(matches['Team1'])
# Out:
# ['Rajasthan Royals',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Rajasthan Royals',
#  'Sunrisers Hyderabad',
#  'Delhi Capitals',
#  'Chennai Super Kings',
#  'Gujarat Titans',
#  'Lucknow Super Giants',
#  'Sunrisers Hyderabad',
#  'Delhi Capitals',
#  'Rajasthan Royals',
#  'Chennai Super Kings',
#  'Kolkata Knight Riders',
#  'Punjab Kings',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Gujarat Titans',
#  'Kolkata Knight Riders',
#  'Chennai Super Kings',
#  'Royal Challengers Bangalore',
#  'Lucknow Super Giants',
#  'Punjab Kings',
#  'Mumbai Indians',
#  'Delhi Capitals',
#  'Royal Challengers Bangalore',
#  'Gujarat Titans',
#  'Rajasthan Royals',
#  'Chennai Super Kings',
#  'Lucknow Super Giants',
#  'Rajasthan Royals',
#  'Royal Challengers Bangalore',
#  'Lucknow Super Giants',
#  'Kolkata Knight Riders',
#  'Sunrisers Hyderabad',
#  'Rajasthan Royals',
#  'Punjab Kings',
#  'Lucknow Super Giants',
#  'Royal Challengers Bangalore',
# ...

# %%
list(matches['Team2'])
# Out:
# ['Gujarat Titans',
#  'Rajasthan Royals',
#  'Lucknow Super Giants',
#  'Gujarat Titans',
#  'Punjab Kings',
#  'Mumbai Indians',
#  'Rajasthan Royals',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Punjab Kings',
#  'Lucknow Super Giants',
#  'Gujarat Titans',
#  'Sunrisers Hyderabad',
#  'Royal Challengers Bangalore',
#  'Mumbai Indians',
#  'Delhi Capitals',
#  'Lucknow Super Giants',
#  'Mumbai Indians',
#  'Delhi Capitals',
#  'Sunrisers Hyderabad',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals',
#  'Gujarat Titans',
#  'Sunrisers Hyderabad',
#  'Chennai Super Kings',
#  'Punjab Kings',
#  'Kolkata Knight Riders',
#  'Sunrisers Hyderabad',
#  'Delhi Capitals',
#  'Mumbai Indians',
#  'Gujarat Titans',
#  'Punjab Kings',
#  'Delhi Capitals',
#  'Gujarat Titans',
#  'Royal Challengers Bangalore',
#  'Chennai Super Kings',
#  'Mumbai Indians',
#  'Sunrisers Hyderabad',
#  'Kolkata Knight Riders',
#  'Delhi Capitals',
# ...

# %%
list(set(list(matches['Team1']) + list(matches['Team2'])))
# Out:
# ['Sunrisers Hyderabad',
#  'Kolkata Knight Riders',
#  'Delhi Daredevils',
#  'Gujarat Titans',
#  'Rising Pune Supergiants',
#  'Delhi Capitals',
#  'Rajasthan Royals',
#  'Chennai Super Kings',
#  'Punjab Kings',
#  'Rising Pune Supergiant',
#  'Royal Challengers Bangalore',
#  'Gujarat Lions',
#  'Lucknow Super Giants',
#  'Deccan Chargers',
#  'Mumbai Indians',
#  'Kings XI Punjab',
#  'Pune Warriors',
#  'Kochi Tuskers Kerala']

# %%
matches.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
team1 = 'Rajasthan Royals'
team2 = 'Royal Challengers Bangalore'

# %%
matches[(((matches['Team1'] == team1) & (matches['Team2'] == team2)) | ((matches['Team1'] == team2) & (matches['Team2'] == team1)))]
# Out:
#           ID       City        Date   Season  MatchNumber  \
# 1    1312199  Ahmedabad  2022-05-27     2022  Qualifier 2
# 35   1304085       Pune  2022-04-26     2022           39
# 61   1304059     Mumbai  2022-04-05     2022           13
# 91   1254103      Dubai  2021-09-29     2021           43
# 118  1254073     Mumbai  2021-04-22     2021           16
# 160  1216522        NaN  2020-10-17  2020/21           33
# 178  1216514  Abu Dhabi  2020-10-03  2020/21           15
# 205  1178424  Bengaluru  2019-04-30     2019           49
# 240  1175369     Jaipur  2019-04-02     2019           14
# 261  1136613     Jaipur  2018-05-19     2018           53
# 303  1136571  Bengaluru  2018-04-15     2018           11
# 435   829819       Pune  2015-05-20     2015   Eliminator
# 464   829763  Bangalore  2015-04-29     2015           29
# 470   829749  Ahmedabad  2015-04-24     2015           22
# 518   733999  Bangalore  2014-05-11     2014           35
# ...

# %%
temp_df = matches[((matches['Team1'] == team1) & (matches['Team2'] == team2)) | ((matches['Team1'] == team2) & (matches['Team2'] == team1))]

# %%
total_matches_bw_two_teams = temp_df.shape[0]
total_matches_bw_two_teams
# Out:
# 27

# %%
temp_df['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Royal Challengers Bangalore    13
# Rajasthan Royals               12
# Name: count, dtype: int64

# %%
temp_df['WinningTeam'].value_counts()['Rajasthan Royals']
# Out:
# 12

# %%
temp_df['WinningTeam'].value_counts()['Royal Challengers Bangalore']
# Out:
# 13

# %%
matches_won_by_team1 = temp_df['WinningTeam'].value_counts()[team1]
matches_won_by_team2 = temp_df['WinningTeam'].value_counts()[team2]

draws = total_matches_bw_two_teams - (matches_won_by_team1 + matches_won_by_team2)
draws
# Out:
# 2

# %%
def team_vs_team(team1, team2):
    temp_df = matches[((matches['Team1'] == team1) & (matches['Team2'] == team2)) | 
    ((matches['Team1'] == team2) & (matches['Team2'] == team1))]
    
    total_matches_bw_two_teams = temp_df.shape[0]

    matches_won_by_team1 = temp_df['WinningTeam'].value_counts()[team1]
    matches_won_by_team2 = temp_df['WinningTeam'].value_counts()[team2]
    
    draws = total_matches_bw_two_teams - (matches_won_by_team1 + matches_won_by_team2)

    response = {
        'Total matches played': total_matches_bw_two_teams,
        'Matches won by ' + team1: matches_won_by_team1,
        'Matches won by ' + team2: matches_won_by_team2,
        'Draw': draws
    }
    
    return response

# %%
team_vs_team('Royal Challengers Bangalore', 'Mumbai Indians')
# Out:
# {'Total matches played': 30,
#  'Matches won by Royal Challengers Bangalore': 13,
#  'Matches won by Mumbai Indians': 17,
#  'Draw': 0}

# %%
list(matches['Player_of_Match'])
# Out:
# ['HH Pandya',
#  'JC Buttler',
#  'RM Patidar',
#  'DA Miller',
#  'Harpreet Brar',
#  'JJ Bumrah',
#  'R Ashwin',
#  'V Kohli',
#  'Q de Kock',
#  'RA Tripathi',
#  'SN Thakur',
#  'TA Boult',
#  'WP Saha',
#  'AD Russell',
#  'JM Bairstow',
#  'DR Sams',
#  'MR Marsh',
#  'Shubman Gill',
#  'JJ Bumrah',
#  'DP Conway',
#  'PWH de Silva',
#  'Avesh Khan',
#  'YBK Jaiswal',
#  'TH David',
#  'DA Warner',
#  'HV Patel',
#  'K Rabada',
#  'RK Singh',
#  'RD Gaikwad',
#  'Mohsin Khan',
#  'SA Yadav',
#  'R Tewatia',
#  'KH Pandya',
#  'Kuldeep Yadav',
#  'Umran Malik',
#  'R Parag',
#  'S Dhawan',
#  'KL Rahul',
#  'M Jansen',
#  'Rashid Khan',
#  'JC Buttler',
#  'Mukesh Choudhary',
#  'Kuldeep Yadav',
#  'F du Plessis',
#  'YS Chahal',
#  'DA Miller',
#  'Umran Malik',
#  'KD Karthik',
#  'KL Rahul',
#  'RA Tripathi',
#  'HH Pandya',
#  'MA Agarwal',
#  'S Dube',
#  'KS Williamson',
#  'YS Chahal',
#  'Kuldeep Yadav',
#  'Anuj Rawat',
#  'Abhishek Sharma',
#  'Shubman Gill',
# ...

# %%
matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
# Team Ka dusri team ke against

# %%
team = 'Chennai Super Kings'
team2 = 'Royal Challengers Bangalore'

# %%
matches_bw_two_teams.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 matches_bw_two_teams.shape[0]
#
# NameError: name 'matches_bw_two_teams' is not defined

# %%
matches_bw_two_teams['WinningTeam'].value_counts()[team]

# %%
matches.Team1

# %%
matches_bw_two_teams[matches_bw_two_teams.WinningTeam == team].shape[0]

# %%
def against(team, team2):
    matches_bw_two_teams = matches[((matches['Team1'] == team) & (matches['Team2'] == team2)) | 
    ((matches['Team2'] == team) & (matches['Team1'] == team2))]
    mp = matches_bw_two_teams.shape[0]
    mw = matches_bw_two_teams['WinningTeam'].value_counts()[team]
    ml = matches_bw_two_teams.shape[0] - matches_bw_two_teams['WinningTeam'].value_counts()[team]
    draw = matches_bw_two_teams.shape[0] - ( matches_bw_two_teams['WinningTeam'].value_counts()[team] +  
                                     matches_bw_two_teams['WinningTeam'].value_counts()[team2])   

    return {
        'Matches played': mp,
        'Matches won': mw,
        'Matches lost': ml,
        'Draw': draw
    }

# %%
against(team, team2)

# %%
# Team ka overall

# %%
def overall(team):
    matches_by_team = matches[(matches.Team1 == team) | (matches.Team2 == team)]
    mp = matches_by_team.shape[0]
    mw = (matches_by_team.WinningTeam == team).sum()
    draw = matches.WinningTeam.isnull().sum()
    sw = ((matches.MatchNumber == 'Final') & (matches.WinningTeam == team)).sum()

    return {
        'Total matches played by ' + team: mp,
        'Matches won': mw,
        'Matches lost': ml,
        'Draws': draw,
        'Season Winner': sw    
    }

# %%
def team_data(team):
    return {
        'Against ' + team2: against(team, team2),
        'Overall': overall(team)
    }

# %%
team_data(team)

# %%
all_teams_ = list(matches.Team1.unique())
all_teams_
# Out:
# ['Rajasthan Royals',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad',
#  'Delhi Capitals',
#  'Chennai Super Kings',
#  'Gujarat Titans',
#  'Lucknow Super Giants',
#  'Kolkata Knight Riders',
#  'Punjab Kings',
#  'Mumbai Indians',
#  'Kings XI Punjab',
#  'Delhi Daredevils',
#  'Rising Pune Supergiant',
#  'Gujarat Lions',
#  'Rising Pune Supergiants',
#  'Pune Warriors',
#  'Deccan Chargers',
#  'Kochi Tuskers Kerala']

# %%
all_teams_.remove(team)

# %%
type(all_teams_)
# Out:
# list

# %%
{team2: against(team, team2) for team2 in all_teams_}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 {team2: against(team, team2) for team2 in all_teams_}
#
# NameError: name 'against' is not defined

# %%
for i in all_teams:
    print(i)
    print(against(team, i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 for i in all_teams:
#       2     print(i)
#       3     print(against(team, i))
#
# NameError: name 'all_teams' is not defined

# %%
def teamAPI(team):
    self_record = allRecord(team)
    TEAMS = matches.Team1.unique()
    against = {team2: team1vsteam2(team, team2) for team2 in TEAMS}
    data = {team: {'overall': self_record,
                   'against': against}}
    return json.dumps(data, cls=NpEncoder)

# %%
matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
# Extract player lists from Team1Players and Team2Players columns, removing brackets and splitting by commas
team1_players = matches['Team1Players'].apply(lambda x: eval(x) if isinstance(x, str) else [])
team2_players = matches['Team2Players'].apply(lambda x: eval(x) if isinstance(x, str) else [])

# Combine all players from both teams into one list
all_players = set()
for players in team1_players:
    all_players.update(players)

for players in team2_players:
    all_players.update(players)

# Convert the set of unique players to a sorted list
unique_players_list = list(sorted(all_players))

print(unique_players_list)
# Out:
# ['A Ashish Reddy', 'A Badoni', 'A Chandila', 'A Chopra', 'A Choudhary', 'A Dananjaya', 'A Flintoff', 'A Kumble', 'A Manohar', 'A Mishra', 'A Mithun', 'A Mukund', 'A Nehra', 'A Nel', 'A Nortje', 'A Singh', 'A Symonds', 'A Tomar', 'A Uniyal', 'A Zampa', 'AA Bilakhia', 'AA Chavan', 'AA Jhunjhunwala', 'AA Kazi', 'AA Noffke', 'AB Agarkar', 'AB Barath', 'AB Dinda', 'AB McDonald', 'AB de Villiers', 'AC Blizzard', 'AC Gilchrist', 'AC Thomas', 'AC Voges', 'AD Hales', 'AD Mascarenhas', 'AD Mathews', 'AD Nath', 'AD Russell', 'AF Milne', 'AG Murtaza', 'AG Paunikar', 'AJ Finch', 'AJ Turner', 'AJ Tye', 'AK Markram', 'AL Menaria', 'AM Nayar', 'AM Rahane', 'AM Salvi', 'AN Ahmed', 'AN Ghosh', 'AP Dole', 'AP Majumdar', 'AP Tare', 'AR Bawne', 'AR Patel', 'AS Joseph', 'AS Rajpoot', 'AS Raut', 'AS Roy', 'AS Yadav', 'AT Carey', 'AT Rayudu', 'AU Rashid', 'AUK Pathan', 'Abdul Samad', 'Abdur Razzak', 'Abhishek Sharma', 'Akash Deep', 'Akash Singh', 'Aman Hakim Khan', 'Anand Rajan', 'Anirudh Singh', 'Ankit Sha
# ...

# %%
matches.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
def do_player_exists(player, player_list):
    return player in player_list

# %%
matches['Team1Players'].apply(do_player_exists(player))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 matches['Team1Players'].apply(do_player_exists(player))
#
# TypeError: do_player_exists() missing 1 required positional argument: 'player_list'

# %%
player = 'V Kohli'

# %%
{
    'Matches played': tmp,
    'Batting record': {
        'Total runs': tr,
        'Strike rate': sr,
        
    }
    'Bowling record': {
        
    }
}
# Out:
#   Cell In[31], line 3
#     'Batting record': {
#                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
def player_exists(player_list):
    return 'V Kohli' in player_list

# %%
matches[matches['Team1Players'].str.join(' ').apply(player_exists)]
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2]
# Index: []
